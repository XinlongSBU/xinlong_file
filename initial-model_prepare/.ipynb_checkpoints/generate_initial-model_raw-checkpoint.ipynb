# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# Read data from mesa data: 
a = pd.read_excel('ONe6040_helm_update.xlsx')

# %%
r_cm = np.array(a["radius_cm"])
rho = np.power(10,np.array(a["logRho"]))
temp = np.array(a["temperature"])
pressure = np.array(a['pressure'])

# %%
data = pd.DataFrame(columns = ['r_center [cm]'],data = r_cm[::-1])
data['density [g/cm3]'] = rho[::-1]
data['temperature [K]'] = temp[::-1]
data['pressure'] = pressure[::-1]
data['neon20'] = np.array(a['ne20'])[::-1]
data['oxygen16'] =  np.array(a['o16'])[::-1]
data['oxygen20'] =  np.array(a['o20'])[::-1]
data['magnesium24'] =  np.array(a['mg24'])[::-1]
data['fluorine20'] =  np.array(a['f20'])[::-1]
data['helium4'] =  np.array(a['he4'])[::-1]
data['aluminum27'] = 0.0
data['silicon28'] =  np.array(a['si28'])[::-1]
data['sulfur32'] = 0.0
data['phosphorus31'] = 0.0
data['hydrogen1'] =  np.array(a['h1'])[::-1]

# %%
data.head(3)
# Out:
#    r_center [cm]  density [g/cm3]  temperature [K]      pressure    neon20  \
# 0    4226.946083     8.348568e+09     6.565855e+08  7.367388e+27  0.007297
# 1    4384.531853     8.348568e+09     6.565856e+08  7.367388e+27  0.007297
# 2    4459.320035     8.348568e+09     6.565856e+08  7.367388e+27  0.007297
#
#    oxygen16  oxygen20   magnesium24    fluorine20       helium4  aluminum27  \
# 0  0.599994  0.392705  4.964879e-16  2.021100e-09  8.924793e-23         0.0
# 1  0.599994  0.392705  4.964889e-16  2.021100e-09  8.924807e-23         0.0
# 2  0.599994  0.392705  4.964890e-16  2.021100e-09  8.924809e-23         0.0
#
#    silicon28  sulfur32  phosphorus31  hydrogen1
# 0   0.000004       0.0           0.0        0.0
# 1   0.000004       0.0           0.0        0.0
# 2   0.000004       0.0           0.0        0.0

# %%
data.shape
# Out:
# (1901, 15)

# %%
df = data[data['temperature [K]']>8.5e8]

# %%
df['temp'] = df['temperature [K]']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_max = df[df['temperature [K]'] == max(df['temperature [K]'])]

# %%
r0 = float(df_max['r_center [cm]'])

# %%
df['temp'] = max(df['temperature [K]'])*np.exp(-(df['r_center [cm]']-r0)**2/3800000000000)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dn = pd.DataFrame(data = [0]*data.shape[0], columns=['temp'])
dn.temp[544:712] = df[(df.index>543) & (df.index<712)]['temp']
dn.temp[0:544] = data['temperature [K]'][0:544]
dn.temp[712:-1] = data['temperature [K]'][712:-1]

# %%
dn.temp[545] = 9.137158e+08
dn.temp[544] = 8.95e+08
dn.temp[543] = 8.83e+08
dn.temp[542] = 8.716119e+08
dn.temp[541] = 8.626356e+08
dn.temp[540] = 8.559116e+08

# %%
dn.temp[710] = 8.675499e+08
dn.temp[711] = 8.614770e+08
dn.temp[712] = 8.567058e+08
dn.temp[713] = 8.496552e+08
dn.temp[714] = 8.428916e+08

# %%
data['temperature [K]'] = dn['temp']

# %%
plt.plot(data['r_center [cm]'],data['temperature [K]'],label='data')
#plt.plot(df['r_center [cm]'],df['temperature [K]'],':',label='df')
#plt.plot(df['r_center [cm]'],df['temp'],':',label='df_temp')
#plt.plot(data['r_center [cm]'],dn['temp'],'o:',label='dn')
plt.plot(r_cm,temp,":",label="MESA")
plt.xlim(5e6,10e6)
plt.ylim(6.e8,11.5e8)
plt.grid()
plt.xlabel("radius [cm]")
plt.ylabel("Temperature [K]")
plt.legend()

# %%
y = np.array(df['density [g/cm3]'][46:150])
x = np.array(df['r_center [cm]'][46:150])
x1 = x[0]
x2 = x[-1]
y1 = y[0]
y2 = y[-1]
y = (y1-y2)/(x1-x2)*(x-x2)+y2
data['density [g/cm3]'][585:689] = y

# %%
plt.plot(data['r_center [cm]'],data['density [g/cm3]'],'-',label='data')
#plt.plot(df['r_center [cm]'],df['density [g/cm3]'],":",label="df")
#plt.plot(x,y,label='y')
plt.plot(r_cm,rho,":",label="MESA")
plt.xlim(7.e6,8.e6)
plt.ylim(7.4e9,7.7e9)
plt.grid()
plt.xlabel("radius [cm]")
plt.ylabel("Density [g/cm^3]")
plt.legend()

# %%
plt.plot(data['r_center [cm]'],data['pressure'],label="data")
plt.plot(r_cm,pressure,":",label="MESA")
plt.xlim(7e6,8.e6)
plt.ylim(6.8e27,7.0e27)
plt.grid()
plt.xlabel("radius [cm]")
plt.ylabel("Pressure [dyn/cm^2]")
plt.legend()

# %%
y = np.array(df['neon20'][46:150])
x = np.array(df['r_center [cm]'][46:150])
x1 = x[0]
x2 = x[-1]
y1 = y[0]
y2 = y[-1]
y = (y1-y2)/(x1-x2)*(x-x2)+y2
data['neon20'][585:689] = y

# %%
plt.plot(data['r_center [cm]'],data['neon20'],"-",label='data')
#plt.plot(df['r_center [cm]'],df['neon20'],":",label="df")
#plt.plot(x,y,label='y')
plt.plot(r_cm,np.array(a['ne20']),":",label="MESA")
plt.plot()
plt.grid()
plt.xlim(7e6,8e6)
plt.ylim(0.15,0.3)
plt.xlabel("radius [cm]")
plt.ylabel("X(ne20)")
plt.legend()

# %%
y = np.array(df['oxygen20'][46:150])
x = np.array(df['r_center [cm]'][46:150])
x1 = x[0]
x2 = x[-1]
y1 = y[0]
y2 = y[-1]
y = (y1-y2)/(x1-x2)*(x-x2)+y2
data['oxygen20'][585:689] = y

# %%
plt.plot(data['r_center [cm]'],data['oxygen20'],"-",label='data')
#plt.plot(df['r_center [cm]'],df['oxygen20'],":",label="df")
#plt.plot(x,y,label='y')
plt.plot(r_cm,np.array(a['o20']),":",label="MESA")
plt.plot()
plt.grid()
plt.xlim(7e6,8e6)
plt.ylim(0.11,0.25)
plt.xlabel("radius [cm]")
plt.ylabel("X(o20)")
plt.legend()

# %%
df['si'] = df['silicon28']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['si'] = max(df['silicon28'])*np.exp(-(df['r_center [cm]']-r0)**2/250000000000)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['silicon28'][548:711] = df.si[9:-1]
data.silicon28[548] = 0.000914

# %%
plt.plot(data['r_center [cm]'],data['silicon28'],"-",label="data")
#plt.plot(df['r_center [cm]'],df['si'],"-",label="df")
plt.plot(r_cm,np.array(a['si28']),":",label="MESA")
#plt.xlim(6.3e6,6.8e6)
#plt.xlim(8.e6,8.5e6)
plt.xlim(6.e6,8.5e6)
#plt.ylim(0,0.004)
plt.xlabel("radius [cm]")
plt.ylabel("X(si28)")
plt.grid()
plt.legend()

# %%
plt.semilogy(data['r_center [cm]'],data['silicon28'],"-",label="data")
plt.grid()
plt.ylim(1e-30,1e-2)
# Out:
# (1e-30, 0.01)

# %%
df['he'] = df['helium4']
df['he'] = max(df['helium4'])*np.exp(-(df['r_center [cm]']-r0)**2/145000000000)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data['helium4'][544:711] = df.he[5:-1]
data.helium4[543] = 5.39028084927776e-20

# %%
plt.plot(data['r_center [cm]'],data['helium4'],'-',label="data")
#plt.plot(df['r_center [cm]'],df['he'],"-",label="df")
plt.plot(r_cm,np.array(a['he4']),":",label="MESA")
plt.grid()
plt.xlim(6e6,8.5e6)
#plt.ylim(2e-20,14e-20)
plt.xlabel("radius [cm]")
plt.ylabel("X(he4)")
plt.legend()

# %%
plt.semilogy(data['r_center [cm]'],data['helium4'],"-",label="data")
plt.grid()
plt.ylim(1e-30,1e-16)
# Out:
# (1e-30, 1e-16)

# %%
df['mg'] = df['magnesium24']
df['mg'] = max(df['magnesium24'])*np.exp(-(df['r_center [cm]']-r0)**2/120000000000)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data['magnesium24'][542:711] = df.mg[3:-1]
data.magnesium24[711] =3.90670155048785e-11

# %%
plt.plot(data['r_center [cm]'],data['magnesium24'],'-',label="data")
#plt.plot(df['r_center [cm]'],df['mg'],"-",label="df")
plt.plot(r_cm,np.array(a['mg24']),":",label="MESA")
plt.grid()
plt.xlim(6e6,8.5e6)
plt.ylim(0,2e-7)
plt.xlabel("radius [cm]")
plt.ylabel("X(mg24)")
plt.legend()

# %%
plt.semilogy(data['r_center [cm]'],data['magnesium24'],"-",label="data")
plt.grid()
plt.ylim(1e-30,1e-6)
# Out:
# (1e-30, 1e-06)

# %%
df['f'] = df['fluorine20']
df['f'] = max(df['fluorine20'])*np.exp(-(df['r_center [cm]']-r0)**2/300000000000)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data['fluorine20'][545:705] = df.f[6:-7]
data.fluorine20[544] = 3.58352270287876e-08
data.fluorine20[705] = 4.89801804094929e-08

# %%
plt.plot(data['r_center [cm]'],data['fluorine20'],'-',label="data")
#plt.plot(df['r_center [cm]'],df['f'],"-",label="df")
plt.plot(r_cm,np.array(a['f20']),":",label="MESA")
plt.grid()
plt.xlim(6.0e6,8.5e6)
plt.ylim(0,6e-7)
plt.xlabel("radius [cm]")
plt.ylabel("X(f20)")
plt.legend()

# %%
plt.semilogy(data['r_center [cm]'],data['fluorine20'],"-",label="data")
plt.grid()
plt.ylim(1e-30,1e-6)
# Out:
# (1e-30, 1e-06)

# %%
data['hydrogen1'] = max(data['hydrogen1'])*np.exp(-(data['r_center [cm]']-r0)**2/120000000000)

# %%
for i in range(len(data.hydrogen1)):
    if data.hydrogen1[i] < 1e-30:
        data.hydrogen1[i] = 1.e-30

# %%
plt.plot(data['r_center [cm]'],data['hydrogen1'],'-',label="data")
#plt.plot(df1['r_center [cm]'],df1['h'],"-o",label="df1")
plt.plot(r_cm,np.array(a['h1']),":",label="MESA")
plt.grid()
plt.xlim(5.0e6,9.5e6)
plt.ylim(0.9e-30,1.75e-25)
plt.xlabel("radius [cm]")
plt.ylabel("X(h1)")
plt.legend()

# %%
plt.semilogy(data['r_center [cm]'],data['hydrogen1'],"-",label="data")
plt.grid()
plt.ylim(0.9e-30,2e-25)
# Out:
# (9e-31, 2e-25)

# %%
plt.plot(data['r_center [cm]'],data['sulfur32'])
plt.xlabel("radius [cm]")
plt.ylabel("X(s32)")
plt.grid()

# %%
plt.plot(data['r_center [cm]'],data['aluminum27'])
plt.xlabel("radius [cm]")
plt.ylabel("X(al27)")
plt.grid()

# %%
plt.plot(data['r_center [cm]'],data['phosphorus31'])
plt.xlabel("radius [cm]")
plt.ylabel("X(p31)")
plt.grid()

# %%
data.oxygen16 = 1-data.hydrogen1-data.helium4-data.oxygen20-data.fluorine20-data.neon20-data.magnesium24-data.aluminum27-data.silicon28-data.phosphorus31-data.sulfur32

plt.plot(data['r_center [cm]'],data['oxygen16'],label="data")
plt.plot(r_cm,np.array(a['o16']),":",label="MESA")
plt.xlim(6e6,10.5e6)
plt.ylim(0.590,0.6005)
plt.grid()
plt.xlabel("radius [cm]")
plt.ylabel("X(o16)")
plt.legend()

# %%
data.head()
# Out:
#    r_center [cm]  density [g/cm3]  temperature [K]      pressure    neon20  \
# 0    4226.946083     8.348568e+09     6.565855e+08  7.367388e+27  0.007297
# 1    4384.531853     8.348568e+09     6.565856e+08  7.367388e+27  0.007297
# 2    4459.320035     8.348568e+09     6.565856e+08  7.367388e+27  0.007297
# 3    4531.537701     8.348568e+09     6.565856e+08  7.367388e+27  0.007297
# 4    4584.575951     8.348568e+09     6.565856e+08  7.367388e+27  0.007297
#
#    oxygen16  oxygen20   magnesium24    fluorine20       helium4  aluminum27  \
# 0  0.599995  0.392705  4.964879e-16  2.021100e-09  8.924793e-23         0.0
# 1  0.599995  0.392705  4.964889e-16  2.021100e-09  8.924807e-23         0.0
# 2  0.599995  0.392705  4.964890e-16  2.021100e-09  8.924809e-23         0.0
# 3  0.599995  0.392705  4.964891e-16  2.021100e-09  8.924810e-23         0.0
# 4  0.599995  0.392705  4.964892e-16  2.021100e-09  8.924811e-23         0.0
#
#    silicon28  sulfur32  phosphorus31     hydrogen1
# ...

# %%
f = open("ECSN-ONe6040-final.raw", "w")

header = '# npts = 1901\n# num of variables = 14\n# density\n# temperature\n# pressure\n# neon-20\n# oxygen-16\n# oxygen-20\n# magnesium-24\n# fluorine-20\n# helium-4\n# aluminum-27\n# silicon-28\n# sulfur-32\n# phosphorus-31\n# hydrogen-1\n'
f.write(header)

for i in range(1901):
    for j in data.columns:
        f.write(str(data[j][i]))
        f.write(' ')
    f.write('\n')
f.close()
